# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\SILICON\Documents\data.csv")
df
# Out:
#         day  temp  windspeed  humidity  event
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny
# 2  1/3/2017    28          2        45   snow
# 3  1/4/2017    24          7        40   snow
# 4  1/5/2017    32          4        35   rain
# 5  1/6/2017    31          2        20  sunny

# %%
# Preparing the dataframe manually
weather_data = [['1/1/2017',32,6,20,'rain'],     
               ['1/2/2017',35,7,30,'sunny'],
               ['1/3/2017',28,2,25,'snow'],
               ['1/4/2017',24,7,45,'snow'],
               ['1/5/2017',32,4,35,'rain'],
               ['1/5/2017',31,2,20,'sunny']]
df1 = pd.DataFrame(weather_data,columns=['day','temp','windspeed','humidity','event'])
df1
# Out:
#         day  temp  windspeed  humidity  event
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny
# 2  1/3/2017    28          2        25   snow
# 3  1/4/2017    24          7        45   snow
# 4  1/5/2017    32          4        35   rain
# 5  1/5/2017    31          2        20  sunny

# %%
df.shape # To print the shape (row and columns) of the dataframe
# Out:
# (6, 5)

# %%
df.columns # TO print the features
# Out:
# Index(['day', 'temp', 'windspeed', 'humidity', 'event'], dtype='object')

# %%
df.head() # To print the first 5 rows of the dataframe
# Out:
#         day  temp  windspeed  humidity  event
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny
# 2  1/3/2017    28          2        45   snow
# 3  1/4/2017    24          7        40   snow
# 4  1/5/2017    32          4        35   rain

# %%
df.head(2) # To print the first two rows
# Out:
#         day  temp  windspeed  humidity  event
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny

# %%
df.tail() # To print the last 5 rows of the dataframe
# Out:
#         day  temp  windspeed  humidity  event
# 1  1/2/2017    35          7        30  sunny
# 2  1/3/2017    28          2        45   snow
# 3  1/4/2017    24          7        40   snow
# 4  1/5/2017    32          4        35   rain
# 5  1/6/2017    31          2        20  sunny

# %%
df.tail(2) # Last tw rows of the dataframe
# Out:
#         day  temp  windspeed  humidity  event
# 4  1/5/2017    32          4        35   rain
# 5  1/6/2017    31          2        20  sunny

# %%
df.sample(3) # Any 3 random sample from the dataframe
# Out:
#         day  temp  windspeed  humidity event
# 4  1/5/2017    32          4        35  rain
# 2  1/3/2017    28          2        45  snow
# 3  1/4/2017    24          7        40  snow

# %%
df1.columns
# Out:
# Index(['day', 'temp', 'windspeed', 'humidity', 'event'], dtype='object')

# %%
df['day']  # printing the data of a single column/feature
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.day  #printing the data of a single column/feature
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['temp','humidity']]
# Out:
#    temp  humidity
# 0    32        20
# 1    35        30
# 2    28        45
# 3    24        40
# 4    32        35
# 5    31        20

# %%
df.describe()  # Describing the stats of the dataframe
# Out:
#             temp  windspeed   humidity
# count   6.000000   6.000000   6.000000
# mean   30.333333   4.666667  31.666667
# std     3.829708   2.338090  10.327956
# min    24.000000   2.000000  20.000000
# 25%    28.750000   2.500000  22.500000
# 50%    31.500000   5.000000  32.500000
# 75%    32.000000   6.750000  38.750000
# max    35.000000   7.000000  45.000000

# %%
df['temp'].describe() # Describing the stats of a particular column (Numerical)
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temp, dtype: float64

# %%
df['event'].describe() # Describing the stats of a particular column (Strings)
# Out:
# count        6
# unique       3
# top       rain
# freq         2
# Name: event, dtype: object

# %%
df.info()   # The information regarding the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   day        6 non-null      object
#  1   temp       6 non-null      int64
#  2   windspeed  6 non-null      int64
#  3   humidity   6 non-null      int64
#  4   event      6 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 368.0+ bytes

# %%
df.iloc[2,4]   # indexed based positioning
# Out:
# 'snow'

# %%
df.iloc[0,4]
# Out:
# 'rain'

# %%
df.loc[2,'temp']
# Out:
# 28

# %% [markdown]
# # Operations

# %%
df['temp'].max() #printing the maximum temp value
# Out:
# 35

# %%
df['temp'].min() #printing the minimum temp value
# Out:
# 24

# %%
df['temp'].std() #Printing the standard deviation of temperature column
# Out:
# 3.8297084310253524

# %%
df['temp'].describe() #checking the std
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temp, dtype: float64

# %%
# for val in df['temp']:
df['temp'] == df['temp'].max()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: temp, dtype: bool

# %%
df[df['temp']==df['temp'].max()]  # Extracting the rows with high temp value
# Out:
#         day  temp  windspeed  humidity  event
# 1  1/2/2017    35          7        30  sunny

# %%
df[df['windspeed']==df['windspeed'].max()].day # Extracting the days with high windspeed value
# Out:
# 1    1/2/2017
# 3    1/4/2017
# Name: day, dtype: object

# %%
df.set_index('day')  # Does not change the original dataframe
# Out:
#           temp  windspeed  humidity  event
# day
# 1/1/2017    32          6        20   rain
# 1/2/2017    35          7        30  sunny
# 1/3/2017    28          2        45   snow
# 1/4/2017    24          7        40   snow
# 1/5/2017    32          4        35   rain
# 1/6/2017    31          2        20  sunny

# %%
df
# Out:
#         day  temp  windspeed  humidity  event
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny
# 2  1/3/2017    28          2        45   snow
# 3  1/4/2017    24          7        40   snow
# 4  1/5/2017    32          4        35   rain
# 5  1/6/2017    31          2        20  sunny

# %%
df.set_index('day',inplace=True) # Changes the original dataframe

# %%
df
# Out:
#           temp  windspeed  humidity  event
# day
# 1/1/2017    32          6        20   rain
# 1/2/2017    35          7        30  sunny
# 1/3/2017    28          2        45   snow
# 1/4/2017    24          7        40   snow
# 1/5/2017    32          4        35   rain
# 1/6/2017    31          2        20  sunny

# %%
df.reset_index(inplace=True)

# %%
df[df['day']=='1/4/2017']  # Displaying the rows with day value 1/4/2017
# Out:
#         day  temp  windspeed  humidity event
# 3  1/4/2017    24          7        40  snow

# %%
df.sort_values(['windspeed'])  # Sorting the dataframe on the basis of windspeed
# Out:
#         day  temp  windspeed  humidity  event
# 2  1/3/2017    28          2        45   snow
# 5  1/6/2017    31          2        20  sunny
# 4  1/5/2017    32          4        35   rain
# 0  1/1/2017    32          6        20   rain
# 1  1/2/2017    35          7        30  sunny
# 3  1/4/2017    24          7        40   snow

# %%
plt.figure(figsize=(10,5))
plt.plot(df1['temp'],df1['humidity'])
plt.xlabel('Temp')
plt.ylabel('humidity')
# plt.legend()
plt.grid('true')
plt.show()

# %% [markdown]
# # Assignment

# %%
data = {'birds':['cranes','cranes','plovers','spoonbills','spoonbills','cranes','plovers','cranes','spoonbills','spoonbills'],
        'age':[3.5,4,1.5,np.nan,6,3,5.5,np.nan,8,4],
        'visits':[2,4,3,4,3,4,2,2,3,2],
        'priority':['yes','yes','no','yes','no','no','no','yes','no','no'],
        'labels':['a','b','c','d','e','f','g','h','i','j']
       }
birds = pd.DataFrame(data)
birds
# Out:
#         birds  age  visits priority labels
# 0      cranes  3.5       2      yes      a
# 1      cranes  4.0       4      yes      b
# 2     plovers  1.5       3       no      c
# 3  spoonbills  NaN       4      yes      d
# 4  spoonbills  6.0       3       no      e
# 5      cranes  3.0       4       no      f
# 6     plovers  5.5       2       no      g
# 7      cranes  NaN       2      yes      h
# 8  spoonbills  8.0       3       no      i
# 9  spoonbills  4.0       2       no      j

# %% [markdown]
# # Q1

# %%
birds.set_index('labels',inplace=True)
birds
# Out:
#              birds  age  visits priority
# labels
# a           cranes  3.5       2      yes
# b           cranes  4.0       4      yes
# c          plovers  1.5       3       no
# d       spoonbills  NaN       4      yes
# e       spoonbills  6.0       3       no
# f           cranes  3.0       4       no
# g          plovers  5.5       2       no
# h           cranes  NaN       2      yes
# i       spoonbills  8.0       3       no
# j       spoonbills  4.0       2       no

# %% [markdown]
# # Q2

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# # Q3

# %%
birds.head(2)
# Out:
#          birds  age  visits priority
# labels
# a       cranes  3.5       2      yes
# b       cranes  4.0       4      yes

# %% [markdown]
# # Q4

# %%
birds[['birds','age']]
# Out:
#              birds  age
# labels
# a           cranes  3.5
# b           cranes  4.0
# c          plovers  1.5
# d       spoonbills  NaN
# e       spoonbills  6.0
# f           cranes  3.0
# g          plovers  5.5
# h           cranes  NaN
# i       spoonbills  8.0
# j       spoonbills  4.0

# %% [markdown]
# # Q5

# %%
birds.iloc[2,'birds']
birds.iloc[3,'age']
birds.iloc[7,'visits']
